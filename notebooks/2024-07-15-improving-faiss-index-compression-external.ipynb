# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Add with ids

# %%
import faiss
from faiss.contrib.datasets import DatasetSIFT1M, SyntheticDataset
import numpy as np

# Work with the most general case: user inserts external ids
ds = DatasetSIFT1M()
# nb = 10_000_000
# nc = int(np.ceil(np.sqrt(nb)))
# ds = SyntheticDataset(d=128, nt=10*nc, nb=nb, nq=100)
db = ds.get_database()
queries = ds.get_queries()
index = faiss.index_factory(ds.d, f'IVF1000,PQ8x8')
# index.verbose = True
index.train(ds.get_train())
np.random.seed(0)
ids = np.random.randint(0, 2**64 - 1, size=len(db), dtype=np.uint64)

# sort database based on ids
perm = np.argsort(ids)
db = db[perm]
ids = ids[perm]

index.add_with_ids(db, ids) # works, the vectors are stored in the underlying index

# %%
# searching will return D, I, and C.
# We can merge I and C, row-wise, and apply ROC.
from faiss.contrib.inspect_tools import get_invlist

byte_savings = 0
IC_bytes = 0
I_bytes = 0
C_bytes = 0
for c in range(index.nlist):
    I, C = get_invlist(index.invlists, c)

    # check if vectors are sorted according to ids
    assert np.all(np.diff(I) > 0)

    # check savings
    byte_savings += np.sum(np.log2(np.arange(2, I.shape[0] + 1)))/8
    IC_bytes += I.nbytes + C.nbytes
    I_bytes += I.nbytes
    C_bytes += C.nbytes

print('Total IC bytes:', IC_bytes)
print('Total I bytes:', I_bytes, 'pct', 100*I_bytes/IC_bytes)
print('Total C bytes:', C_bytes, 'pct', 100*C_bytes/IC_bytes)
print('Total bytes saved:', byte_savings, 'pct IC', 100*byte_savings/IC_bytes)
print('Total bytes saved:', byte_savings, 'pct I', 100*byte_savings/I_bytes)
print('Total bytes saved:', byte_savings, 'pct C', 100*byte_savings/C_bytes)
# Out:
# Total IC bytes: 16000000
# Total I bytes: 8000000 pct 50.0
# Total C bytes: 8000000 pct 50.0
# Total bytes saved: 1079392.2928356656 pct IC 6.74620183022291
# Total bytes saved: 1079392.2928356656 pct I 13.49240366044582
# Total bytes saved: 1079392.2928356656 pct C 13.49240366044582

# %%
# merge external ids and codes
from ipynb_helper_functions import compute_empirical_entropy_from_freqs
from sortedcontainers import SortedList

def merge_ids_and_codes(I, C):
    assert C.dtype == np.uint8
    return np.concatenate([I.view(dtype=np.uint8).reshape(I.shape[0], -1),C], axis=1)

# for a single cluster
I, C = get_invlist(index.invlists, 23)
IC = merge_ids_and_codes(I, C)
sorted_list = SortedList([ic.tobytes() for ic in IC])
sorted_list
# Out:
# SortedList([b'\x00\x0e\x9fz\x03\xd4\x14\xbfZ\nO\xe9H\xe4\xe2\xa0', b'\x006>a\x03\x94\xc1l\x8e\xcfO\xd4H\x87d\xe1', b'\x00P\xb1\xfb\x8e\xddC\xcfQx)\xafd:\x92c', b'\x00R\xba\xd8\x84\xc6\xfds\x90\xf6\xfdou\x12yd', b'\x00\xd2\xe6G\xbe\r\xe3\x05Q\x9b8\xcb2/\x05v', b'\x00\xe8\xcdo\xde\xba\x1f\x8b:b\xe8gDuQ\x1b', b'\x01W\xb8\xde\xdf\xd0\xa9F\xbe\n\xb8YH\\\xa3\x87',
# %% [markdown]
# # Distribution of ids+codes?

# %%
# ids are uniformely distributed
for c in range(index.nlist):
    I, C = get_invlist(index.invlists, c)
    print(c, np.diff(I).mean()/(ids.max()/(I.shape[0] - 1)))
# Out:
# 0 0.9995856552065747
# 1 0.9954581004782932
# 2 0.9972266522889327
# 3 0.9998551082784807
# 4 0.9991571343510857
# 5 0.996145930526675
# 6 0.9982782088438371
# 7 0.9947434157424858
# 8 0.9977252207056426
# 9 0.9993663691335491
# 10 0.999584308834924
# 11 0.9996995703956455
# 12 0.9918125096256524
# 13 0.994780475296742
# 14 0.9977434506673541
# 15 0.9982699710676107
# 16 0.9908324107331739
# 17 0.9992640242131867
# 18 0.9980690249209537
# 19 0.9916941963110376
# 20 0.9961823670162233
# 21 0.9984100597988549
# 22 0.9976308499935738
# 23 0.9989930515340121
# 24 0.9993557450258777
# 25 0.9986346828988482
# 26 0.9965600294816956
# 27 0.9969917471484004
# 28 0.9985608421786563
# 29 0.9988839706559625
# 30 0.9965892123932111
# 31 0.9950228620122472
# 32 0.9972160777436486
# 33 0.9987687993180034
# 34 0.9986733289079319
# 35 0.9994618885657133
# 36 0.9987855782863189
# 37 0.9990649286219188
# 38 0.9986995372266991
# 39 0.9977466984897521
# 40 0.9984664559453604
# 41 0.9995666803097946
# 42 0.9986180028277871
# 43 0.9985872330523897
# 44 0.9987841253532912
# 45 0.9991645856704812
# 46 0.9993186531290352
# 47 0.9918676932569599
# 48 0.9966797268611595
# 49 0.9982866835758303
# 50 0.998653916128681
# 51 0.9998877354358969
# 52 0.9947379103478627
# 53 0.9989902746320296
# 54 0.9994712886422712
# 55 0.9986077998755276
# 56 0.9975399210846028
# 57 0.9995588401492961
# 58 0.9970414681365034
# 59 0.9925366553614393
# 60 0.9993545836228421
# 61 0.9967615394792174
# 62 0.998470913611717
# 63 0.9985224135783666
# 64 0.9978386571379833
# 65 0.9967551971798234
# 66 0.9988539815954227
# 67 0.9978862258047224
# 68 0.9982497346266118
# 69 0.999111072181019
# 70 0.9992598371613781
# 71 0.9990932593468559
# 72 0.9970904232185277
# 73 0.9964982959701667
# 74 0.999168598154338
# 75 0.9951462308267882
# 76 0.9977382752345582
# 77 0.9985227807250738
# 78 0.9992043892681889
# 79 0.9995385623954806
# 80 0.9951427308023347
# 81 0.9981801192301784
# 82 0.9927370864502006
# 83 0.9970495290221472
# 84 0.9958988826514769
# 85 0.9996611452494811
# 86 0.9993942975820659
# 87 0.9993786721308795
# 88 0.9985449828959214
# 89 0.9981371910466607
# 90 0.9987268830704239
# 91 0.9984997237949754
# 92 0.9988306871016945
# 93 0.9998044031686234
# 917 0.998442318741685
# 918 0.9979789134100201
# 919 0.9992659737793718
# 920 0.99893705677886
# 921 0.9977336683014916
# 922 0.998053955628262
# 923 0.9987074686361053
# 924 0.9986383248246581
# 925 0.9958563160921121
# 926 0.999715203411815
# 927 0.9984377815017992
# 928 0.9963839853822799
# 929 0.9974274954209085
# 930 0.9972476408902565
# 931 0.9970720038335255
# 932 0.9988859166024826
# 933 0.9984170947036798
# 934 0.9973678218163932
# 935 0.9924076150808222
# 936 0.9977567076741681
# 937 0.9952083790297204
# 938 0.9993337987586114
# 939 0.9923197160185201
# 940 0.9970990190107134
# 941 0.9953874657798845
# 942 0.9986921313481578
# 943 0.9988738975970279
# 944 0.9955737308953038
# 945 0.9983328658889568
# 946 0.9948514123172986
# 947 0.9998038684076598
# 948 0.998202535333384
# 949 0.9973846671485972
# 950 0.9983490602985394
# 951 0.9949127984131283
# 952 0.9970717901904935
# 953 0.9970971288352867
# 954 0.99864630683931
# 955 0.9994870921338297
# 956 0.9971193042042885
# 957 0.9963583169705457
# 958 0.9889959739692171
# 959 0.9981344547952575
# 960 0.9997968774987117
# 961 0.9943711062404615
# 962 0.9989093349984592
# 963 0.9971666362776573
# 964 0.9985284569183484
# 965 0.9975490306515106
# 966 0.9962667280038182
# 967 0.998317842316495
# 968 0.9989091450465888
# 969 0.9913469054560251
# 970 0.9983703143736554
# 971 0.99522082822879
# 972 0.9994149279084206
# 973 0.997110122861891
# 974 0.9974163547360441
# 975 0.9986414913654419
# 976 0.9992811860658447
# 977 0.9979397165082323
# 978 0.9983208292911003
# 979 0.9983965794504278
# 980 0.9988202666510486
# 981 0.9935036840389081
# 982 0.9971305543681144
# 983 0.9987388864890653
# 984 0.9992611979771308
# 985 0.9987407920959761
# 986 0.9971717280078021
# 987 0.9994680807904822
# 988 0.9935362610892731
# 989 0.998413654308589
# 990 0.999220579345454
# 991 0.9990038758781493
# 992 0.9970638356380314
# 993 0.9942890033764976
# 994 0.9995566729709331
# 995 0.9827140816920312
# 996 0.9924636376867272
# 997 0.9963642803504181
# 998 0.9991758045863222
# 999 0.9958844719509194

# %%
from ipynb_helper_functions import compute_empirical_entropy_from_freqs

# anything to gain entropy coding the codes? unlikely
IC_all = np.concatenate([merge_ids_and_codes(*get_invlist(index.invlists, c)) for c in range(index.nlist)], axis=0)
for col in range(IC_all.shape[1]):
    x = IC_all[:, col]
    print('col', col, compute_empirical_entropy_from_freqs(x))
# Out:
# col 0 7.999817261997368
# col 1 7.9997987258051095
# col 2 7.999834987639778
# col 3 7.999817910636274
# col 4 7.99981792704093
# col 5 7.999788495176301
# col 6 7.999803393891999
# col 7 7.999841077288339
# col 8 7.834437745055748
# col 9 7.852393143294568
# col 10 7.855576223093281
# col 11 7.878637296368633
# col 12 7.851141442733805
# col 13 7.871556847076469
# col 14 7.838555855301651
# col 15 7.850192316702203

# %% [markdown]
# # Compress codes only

# %%
import faiss
from faiss.contrib.datasets import DatasetSIFT1M, SyntheticDataset, DatasetGIST1M
import numpy as np

# Work with the most general case: user inserts external ids
ds = DatasetGIST1M()
db = ds.get_database()
queries = ds.get_queries()
index = faiss.index_factory(ds.d, f'IVF1000,PQ8x8')
index.verbose = True
index.train(ds.get_train())
index.add(db)

# sort database based on codes
perm = []
for c in range(index.nlist):
    I, C = get_invlist(index.invlists, c)
    # perm.append(I[np.argsort(C[:, 0])])
    perm.append(I[np.lexsort(C[:, ::-1].T)])
perm = np.concatenate(perm)
index.reset()
index.add(db[perm]) # works, the vectors are stored in the underlying index
# Out:
# Training level-1 quantizer
# Training level-1 quantizer on 100000 vectors in 960D
# Training IVF residual
#   Input training set too big (max size is 65536), sampling 65536 / 100000 vectors
# doing polysemous training for PQ
# precomputing IVFPQ tables type 1
# IndexIVFPQ::add_core_o: adding 0:32768 / 1000000
#  add_core times: 0.000 210.631 3.884
# IndexIVFPQ::add_core_o: adding 32768:65536 / 1000000
#  add_core times: 0.000 221.514 2.458
# IndexIVFPQ::add_core_o: adding 65536:98304 / 1000000
#  add_core times: 0.000 206.478 2.393
# IndexIVFPQ::add_core_o: adding 98304:131072 / 1000000
#  add_core times: 0.000 182.924 2.269
# IndexIVFPQ::add_core_o: adding 131072:163840 / 1000000
#  add_core times: 0.000 183.862 2.272
# IndexIVFPQ::add_core_o: adding 163840:196608 / 1000000
#  add_core times: 0.001 200.333 2.234
# IndexIVFPQ::add_core_o: adding 196608:229376 / 1000000
#  add_core times: 0.000 183.920 2.153
# IndexIVFPQ::add_core_o: adding 229376:262144 / 1000000
#  add_core times: 0.000 182.511 2.205
# IndexIVFPQ::add_core_o: adding 262144:294912 / 1000000
#  add_core times: 0.000 185.370 2.221
# IndexIVFPQ::add_core_o: adding 294912:327680 / 1000000
#  add_core times: 0.000 183.864 2.200
# IndexIVFPQ::add_core_o: adding 327680:360448 / 1000000
#  add_core times: 0.000 185.043 2.255
# IndexIVFPQ::add_core_o: adding 360448:393216 / 1000000
#  add_core times: 0.000 184.251 2.071
# IndexIVFPQ::add_core_o: adding 393216:425984 / 1000000
#  add_core times: 0.000 184.804 2.073
# IndexIVFPQ::add_core_o: adding 425984:458752 / 1000000
#  add_core times: 0.000 183.211 2.076
# IndexIVFPQ::add_core_o: adding 458752:491520 / 1000000
#  add_core times: 0.000 183.268 2.099
# IndexIVFPQ::add_core_o: adding 491520:524288 / 1000000
#  add_core times: 0.000 210.656 2.129
# IndexIVFPQ::add_core_o: adding 524288:557056 / 1000000
#  add_core times: 0.000 184.817 2.045
# IndexIVFPQ::add_core_o: adding 557056:589824 / 1000000
#  add_core times: 0.000 184.460 2.034
# IndexIVFPQ::add_core_o: adding 589824:622592 / 1000000
#  add_core times: 0.000 185.204 2.025
# IndexIVFPQ::add_core_o: adding 622592:655360 / 1000000
#  add_core times: 0.000 183.471 2.267
# IndexIVFPQ::add_core_o: adding 655360:688128 / 1000000
#  add_core times: 0.000 191.019 2.334
# IndexIVFPQ::add_core_o: adding 688128:720896 / 1000000
#  add_core times: 0.000 184.033 2.268
# IndexIVFPQ::add_core_o: adding 720896:753664 / 1000000
#  add_core times: 0.000 185.025 2.197
# IndexIVFPQ::add_core_o: adding 753664:786432 / 1000000
#  add_core times: 0.000 183.315 2.117
# IndexIVFPQ::add_core_o: adding 786432:819200 / 1000000
#  add_core times: 0.000 183.713 2.200
# IndexIVFPQ::add_core_o: adding 819200:851968 / 1000000
#  add_core times: 0.000 184.677 2.162
# IndexIVFPQ::add_core_o: adding 851968:884736 / 1000000
#  add_core times: 0.000 183.476 2.229
# IndexIVFPQ::add_core_o: adding 884736:917504 / 1000000
#  add_core times: 0.000 184.101 2.190
# IndexIVFPQ::add_core_o: adding 917504:950272 / 1000000
#  add_core times: 0.000 186.785 4.694
# IndexIVFPQ::add_core_o: adding 950272:983040 / 1000000
#  add_core times: 0.001 182.770 2.614
# IndexIVFPQ::add_core_o: adding 983040:1000000 / 1000000
#  add_core times: 0.000 97.408 1.467
# IndexIVFPQ::add_core_o: adding 0:32768 / 1000000
#  add_core times: 0.000 180.241 1.323
# IndexIVFPQ::add_core_o: adding 32768:65536 / 1000000
#  add_core times: 0.001 180.338 1.297
# IndexIVFPQ::add_core_o: adding 65536:98304 / 1000000
#  add_core times: 0.000 184.426 1.331
# IndexIVFPQ::add_core_o: adding 98304:131072 / 1000000
#  add_core times: 0.000 184.175 1.448
# IndexIVFPQ::add_core_o: adding 131072:163840 / 1000000
#  add_core times: 0.000 186.575 1.300
# IndexIVFPQ::add_core_o: adding 163840:196608 / 1000000
#  add_core times: 0.000 185.220 1.333
# IndexIVFPQ::add_core_o: adding 196608:229376 / 1000000
#  add_core times: 0.000 186.949 1.339
# IndexIVFPQ::add_core_o: adding 229376:262144 / 1000000
#  add_core times: 0.001 184.987 1.317
# IndexIVFPQ::add_core_o: adding 262144:294912 / 1000000
#  add_core times: 0.000 185.689 1.318
# IndexIVFPQ::add_core_o: adding 294912:327680 / 1000000
#  add_core times: 0.000 186.583 1.334
# IndexIVFPQ::add_core_o: adding 327680:360448 / 1000000
#  add_core times: 0.001 185.418 1.342
# IndexIVFPQ::add_core_o: adding 360448:393216 / 1000000
#  add_core times: 0.000 184.773 1.365
# IndexIVFPQ::add_core_o: adding 393216:425984 / 1000000
#  add_core times: 0.000 186.468 1.331
# IndexIVFPQ::add_core_o: adding 425984:458752 / 1000000
#  add_core times: 0.000 185.906 1.324
# IndexIVFPQ::add_core_o: adding 458752:491520 / 1000000
#  add_core times: 0.001 185.331 1.344
# IndexIVFPQ::add_core_o: adding 491520:524288 / 1000000
#  add_core times: 0.000 186.019 1.325
# IndexIVFPQ::add_core_o: adding 524288:557056 / 1000000
#  add_core times: 0.001 186.592 1.316
# IndexIVFPQ::add_core_o: adding 557056:589824 / 1000000
#  add_core times: 0.000 185.919 1.327
# IndexIVFPQ::add_core_o: adding 589824:622592 / 1000000
#  add_core times: 0.000 185.923 1.301
# IndexIVFPQ::add_core_o: adding 622592:655360 / 1000000
#  add_core times: 0.000 187.607 1.375
# IndexIVFPQ::add_core_o: adding 655360:688128 / 1000000
#  add_core times: 0.000 184.819 1.311
# IndexIVFPQ::add_core_o: adding 688128:720896 / 1000000
#  add_core times: 0.000 189.141 1.298
# IndexIVFPQ::add_core_o: adding 720896:753664 / 1000000
#  add_core times: 0.000 185.558 1.297
# IndexIVFPQ::add_core_o: adding 753664:786432 / 1000000
#  add_core times: 0.000 185.593 1.305
# IndexIVFPQ::add_core_o: adding 786432:819200 / 1000000
#  add_core times: 0.000 185.293 1.324
# IndexIVFPQ::add_core_o: adding 819200:851968 / 1000000
#  add_core times: 0.001 198.920 1.414
# IndexIVFPQ::add_core_o: adding 851968:884736 / 1000000
#  add_core times: 0.000 272.321 1.407
# IndexIVFPQ::add_core_o: adding 884736:917504 / 1000000
#  add_core times: 0.001 185.799 1.333
# IndexIVFPQ::add_core_o: adding 917504:950272 / 1000000
#  add_core times: 0.001 185.732 1.315
# IndexIVFPQ::add_core_o: adding 950272:983040 / 1000000
#  add_core times: 0.000 185.497 1.315
# IndexIVFPQ::add_core_o: adding 983040:1000000 / 1000000
#  add_core times: 0.000 96.208 0.700

# %%
print(np.all(np.diff(I.astype(np.int32)) > 0))
C_all = [get_invlist(index.invlists, c)[1] for c in range(index.nlist)]
assert all(np.all(np.diff(C_all[c][:, 0]) >= 0) for c in range(index.nlist))
# Out:
# True

# %%
# estimate savings
byte_savings = 0
C_bytes = 0
for c in range(index.nlist):
    I, C = get_invlist(index.invlists, c)

    # check if vectors are sorted according to ids
    assert np.all(np.diff(I) > 0)

    # check savings
    byte_savings += np.sum(np.log2(np.arange(2, I.shape[0] + 1)))/8
    C_bytes += C.nbytes

print('Total C bytes', C_bytes)
print('Total C bytes per element:', C_bytes/index.ntotal)
print('Total bytes saved:', byte_savings, 'pct C', 100*byte_savings/C_bytes)
print('Total bytes saved per element:', byte_savings/index.ntotal, 'pct C', 100*byte_savings/C_bytes)
# Out:
# Total C bytes 8000000
# Total C bytes per element: 8.0
# Total bytes saved: 1123774.1140941458 pct C 14.047176426176824
# Total bytes saved per element: 1.1237741140941457 pct C 14.047176426176824

# %% [markdown]
# # One-shot permutation decoding

# %%
from numpy.typing import NDArray
import numpy as np

rng = np.random.default_rng()



perm = np.array([1,5,0,6,3,4,2], dtype=np.uint32)

lehmer_encode_inplace(perm)
assert np.all(perm == np.array([1, 4, 0, 3, 1, 1, 0], dtype=np.uint32))

lehmer_decode_inplace(perm)
assert np.all(perm == np.array([1,5,0,6,3,4,2], dtype=np.uint32))

# %%
# %load_ext autoreload
# %autoreload 2

from rpc.codecs import VectorizedPermutationCodec
from craystack.rans import base_message
import numpy as np

rng = np.random.default_rng()

n = 10_000
d = 130

ans_state = base_message(shape=d)
perm = rng.permutation(n)
codec = VectorizedPermutationCodec(n, d)
ans_state = codec.encode(perm, ans_state)
# %time _, perm_dec = codec.decode(ans_state)
assert np.all(perm == perm_dec)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# CPU times: user 48.7 ms, sys: 17 μs, total: 48.7 ms
# Wall time: 48.7 ms
